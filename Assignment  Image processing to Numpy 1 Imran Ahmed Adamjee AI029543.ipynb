# %%
from PIL import Image
import numpy as np
import matplotlib.pylab as plt
import os
from os.path import join
# %matplotlib inline

pics_list=[]

for dirpath,dirnames,filenames in os.walk('/Users/ABC/OneDrive/Desktop/Pil picture/'):
    print('currentpath',dirpath)
    print('directories',dirnames)
    for file in filenames:
        #print('Files:',file)
        path=join(dirpath,file)
        #print(path)
        pics_list.append(path)

a = int(input('Enter picture number to resize:'))
if a<=20:
    print(pics_list[a]) 
    im1 = plt.imread(pics_list[a])
    plt.imshow(im1, interpolation="None")#, **kwargs)
    im=Image.open(pics_list[a])
    im
    im.show()
    print('Pil Image')
    print('Matplotlib Image')

    print(type(im1))
    print('Original pic shape:',im1.shape)
    print('Original pic size:',im.size)
    print('Original pic color:',im.mode)
    print('Original pic format:',im.format)
# Out:
# currentpath /Users/ABC/OneDrive/Desktop/Pil picture/
# directories []
# Enter picture number to resize:7
# /Users/ABC/OneDrive/Desktop/Pil picture/cat-animal.jpg
# Pil Image
# Matplotlib Image
# <class 'numpy.ndarray'>
# Original pic shape: (768, 1024, 3)
# Original pic size: (1024, 768)
# Original pic color: RGB
# Original pic format: JPEG

# %%
im_resize=im.resize((480,256))
print(im_resize.format)
print(im_resize.mode)
print('Resize pic size:' ,im_resize.size)

i=np.asarray(im_resize)
print('Resize pic shape:',i.shape)
print('Resize pic ndim:',i.ndim)
print(type(i))
print(i)
im_resize
#im_resize.show()
# Out:
# None
# RGB
# Resize pic size: (480, 256)
# Resize pic shape: (256, 480, 3)
# Resize pic ndim: 3
# <class 'numpy.ndarray'>
# [[[ 18  16   1]
#   [ 18  16   3]
#   [ 16  17   3]
#   ...
#   [ 69  96  53]
#   [ 75 102  59]
#   [ 40  67  26]]
#
#  [[ 13  10   3]
#   [ 12   9   2]
#   [  9   8   3]
#   ...
#   [ 21  45  11]
#   [  1  25   0]
#   [  3  27   0]]
#
#  [[  8   4   3]
#   [  6   2   3]
#   [  2   0   3]
#   ...
#   [ 21  37  11]
#   [ 11  26   3]
#   [  3  18   0]]
#
#  ...
#
#  [[ 84  38  15]
#   [ 84  39  18]
#   [ 95  50  29]
#   ...
#   [115  49  27]
#   [119  53  31]
#   [112  46  24]]
#
#  [[ 90  44  21]
#   [ 84  39  18]
#   [ 88  43  22]
#   ...
#   [112  46  24]
#   [106  40  18]
#   [115  49  27]]
#
#  [[ 94  48  25]
#   [ 87  42  21]
#   [ 85  40  19]
#   ...
#   [116  50  28]
#   [121  55  33]
#   [115  49  27]]]
# <PIL.Image.Image image mode=RGB size=480x256 at 0x22D7415AF60>
